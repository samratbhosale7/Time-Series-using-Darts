# %%
# !pip install darts
# Out:
# Collecting darts
#   Downloading darts-0.24.0-py3-none-any.whl (693 kB)
#      -------------------------------------- 693.9/693.9 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (1.10.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (1.2.1)
# Collecting tensorboardX>=2.1
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      -------------------------------------- 114.5/114.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (4.64.1)
# Collecting statsforecast>=1.4
#   Downloading statsforecast-1.5.0-py3-none-any.whl (99 kB)
#      -------------------------------------- 100.0/100.0 kB 6.0 MB/s eta 0:00:00
# Collecting holidays>=0.11.1
#   Downloading holidays-0.25-py3-none-any.whl (514 kB)
#      -------------------------------------- 514.2/514.2 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (3.7.0)
# Collecting pyod>=0.9.5
#   Downloading pyod-1.0.9.tar.gz (149 kB)
#      -------------------------------------- 150.0/150.0 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting shap>=0.40.0
#   Downloading shap-0.41.0-cp310-cp310-win_amd64.whl (435 kB)
#      -------------------------------------- 435.6/435.6 kB 9.0 MB/s eta 0:00:00
# Collecting pytorch-lightning>=1.5.0
#   Downloading pytorch_lightning-2.0.2-py3-none-any.whl (719 kB)
#      ------------------------------------- 719.0/719.0 kB 11.3 MB/s eta 0:00:00
# Collecting xgboost>=1.6.0
#   Downloading xgboost-1.7.5-py3-none-win_amd64.whl (70.9 MB)
#      ---------------------------------------- 70.9/70.9 MB 3.9 MB/s eta 0:00:00
# Collecting catboost>=1.0.6
#   Downloading catboost-1.2-cp310-cp310-win_amd64.whl (101.0 MB)
#      -------------------------------------- 101.0/101.0 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (1.5.3)
# Collecting pmdarima>=1.8.0
#   Downloading pmdarima-2.0.3-cp310-cp310-win_amd64.whl (569 kB)
#      -------------------------------------- 569.7/569.7 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (2.28.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (1.12.1)
# Collecting lightgbm>=3.2.0
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.16.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (1.1.1)
# Collecting nfoursid>=1.0.0
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Collecting prophet>=1.1.1
#   Downloading prophet-1.1.4-py3-none-win_amd64.whl (12.9 MB)
#      --------------------------------------- 12.9/12.9 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (1.23.5)
# Requirement already satisfied: statsmodels>=0.13.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (0.13.5)
# Requirement already satisfied: xarray>=0.17.0 in c:\users\sambh\anaconda3\lib\site-packages (from darts) (2022.11.0)
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.0/44.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\sambh\anaconda3\lib\site-packages (from catboost>=1.0.6->darts) (1.16.0)
# Requirement already satisfied: plotly in c:\users\sambh\anaconda3\lib\site-packages (from catboost>=1.0.6->darts) (5.9.0)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\sambh\anaconda3\lib\site-packages (from holidays>=0.11.1->darts) (2.8.2)
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: wheel in c:\users\sambh\anaconda3\lib\site-packages (from lightgbm>=3.2.0->darts) (0.38.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sambh\anaconda3\lib\site-packages (from matplotlib>=3.3.0->darts) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sambh\anaconda3\lib\site-packages (from pandas>=1.0.5->darts) (2022.7)
# Requirement already satisfied: urllib3 in c:\users\sambh\anaconda3\lib\site-packages (from pmdarima>=1.8.0->darts) (1.26.14)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-0.29.35-py2.py3-none-any.whl (988 kB)
#      ------------------------------------- 988.4/988.4 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\sambh\anaconda3\lib\site-packages (from pmdarima>=1.8.0->darts) (65.6.3)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.9/47.9 kB 2.5 MB/s eta 0:00:00
# Collecting importlib-resources
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.2/83.2 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.51 in c:\users\sambh\anaconda3\lib\site-packages (from pyod>=0.9.5->darts) (0.56.4)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ------------------------------------- 519.2/519.2 kB 10.8 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.7.0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\sambh\anaconda3\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in c:\users\sambh\anaconda3\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (2022.11.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sambh\anaconda3\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sambh\anaconda3\lib\site-packages (from requests>=2.22.0->darts) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sambh\anaconda3\lib\site-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sambh\anaconda3\lib\site-packages (from requests>=2.22.0->darts) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sambh\anaconda3\lib\site-packages (from scikit-learn>=1.0.1->darts) (2.2.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in c:\users\sambh\anaconda3\lib\site-packages (from shap>=0.40.0->darts) (2.0.0)
# Collecting fugue>=0.8.1
#   Downloading fugue-0.8.4-py3-none-any.whl (372 kB)
#      ------------------------------------- 372.2/372.2 kB 11.7 MB/s eta 0:00:00
# Collecting plotly-resampler
#   Downloading plotly_resampler-0.8.3.2.tar.gz (46 kB)
#      ---------------------------------------- 46.4/46.4 kB ? eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: patsy>=0.5.2 in c:\users\sambh\anaconda3\lib\site-packages (from statsmodels>=0.13.0->darts) (0.5.3)
# Collecting protobuf<4,>=3.8.0
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#      ------------------------------------- 904.0/904.0 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\sambh\anaconda3\lib\site-packages (from tqdm>=4.60.0->darts) (0.4.6)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.4-cp310-cp310-win_amd64.whl (319 kB)
#      ------------------------------------- 319.8/319.8 kB 10.0 MB/s eta 0:00:00
# Collecting triad>=0.8.8
#   Downloading triad-0.8.9-py3-none-any.whl (53 kB)
#      ---------------------------------------- 53.7/53.7 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\sambh\anaconda3\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (3.1.2)
# Collecting sqlglot
#   Downloading sqlglot-15.0.0-py3-none-any.whl (266 kB)
#      ------------------------------------- 266.4/266.4 kB 17.1 MB/s eta 0:00:00
# Collecting fugue-sql-antlr>=0.1.6
#   Downloading fugue-sql-antlr-0.1.6.tar.gz (154 kB)
#      -------------------------------------- 154.6/154.6 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyarrow>=0.15.1
#   Downloading pyarrow-12.0.0-cp310-cp310-win_amd64.whl (21.5 MB)
#      ---------------------------------------- 21.5/21.5 MB 9.6 MB/s eta 0:00:00
# Collecting qpd>=0.4.1
#   Downloading qpd-0.4.1-py3-none-any.whl (187 kB)
#      -------------------------------------- 187.9/187.9 kB 5.7 MB/s eta 0:00:00
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.4-cp310-cp310-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\sambh\anaconda3\lib\site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.39.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sambh\anaconda3\lib\site-packages (from plotly->catboost>=1.0.6->darts) (8.0.1)
# Collecting dash<3.0.0,>=2.2.0
#   Downloading dash-2.10.2-py3-none-any.whl (10.3 MB)
#      --------------------------------------- 10.3/10.3 MB 10.9 MB/s eta 0:00:00
# Collecting jupyter-dash>=0.4.2
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
#      ------------------------------------- 185.2/185.2 kB 10.9 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.9.0-cp310-none-win_amd64.whl (191 kB)
#      ------------------------------------- 191.7/191.7 kB 11.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sambh\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (22.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\sambh\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (2.2.2)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\sambh\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (2.2.2)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting antlr4-python3-runtime<4.12,>=4.11.1
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      -------------------------------------- 144.2/144.2 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: ipython in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (8.10.0)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (1.5.6)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: ipykernel in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (6.19.2)
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      -------------------------------------- 135.3/135.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sambh\anaconda3\lib\site-packages (from jinja2->fugue>=0.8.1->statsforecast>=1.4->darts) (2.1.1)
# Requirement already satisfied: click>=8.0 in c:\users\sambh\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (8.0.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\sambh\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (2.0.1)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\sambh\anaconda3\lib\site-packages (from fs->triad>=0.8.8->fugue>=0.8.1->statsforecast>=1.4->darts) (1.4.4)
# Requirement already satisfied: psutil in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (6.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (1.5.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.1.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.7.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\sambh\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (23.2.0)
# Requirement already satisfied: decorator in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.1.1)
# Requirement already satisfied: backcall in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\sambh\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (3.0.36)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sambh\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.2.0)
# Requirement already satisfied: entrypoints in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.4)
# Requirement already satisfied: wcwidth in c:\users\sambh\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.5)
# Requirement already satisfied: asttokens in c:\users\sambh\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\sambh\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.2)
# Requirement already satisfied: executing in c:\users\sambh\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sambh\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (305.1)
# Building wheels for collected packages: pyod, plotly-resampler, fugue-sql-antlr, pymeeus
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.9-py3-none-any.whl size=184163 sha256=b953c64c81c63463e15c78bc685774dbedcabe0283f0da420c2a675db56bbccf
#   Stored in directory: c:\users\sambh\appdata\local\pip\cache\wheels\8a\a9\b2\5db1f8c7dce5b24cee7c7254d162261df6bd85231a51867f1c
#   Building wheel for plotly-resampler (pyproject.toml): started
#   Building wheel for plotly-resampler (pyproject.toml): finished with status 'done'
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.3.2-cp310-cp310-win_amd64.whl size=47902 sha256=de6a68191183347f55409d339cd1c21cc382fe230e11f849ba47c26be47f3135
#   Stored in directory: c:\users\sambh\appdata\local\pip\cache\wheels\98\28\a7\22e9c97d088da8bce7388071fda070b77df23816e7b6671f21
#   Building wheel for fugue-sql-antlr (setup.py): started
#   Building wheel for fugue-sql-antlr (setup.py): finished with status 'done'
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.6-py3-none-any.whl size=158069 sha256=74b1cd187bd7256a0a4710619ba8c359c24a5940afdfd90a5636b83391650d6e
#   Stored in directory: c:\users\sambh\appdata\local\pip\cache\wheels\8f\f3\c4\9e26cf67253133cb9c7c23f1769e71aa8be2b75ee9da6a8e46
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732051 sha256=fd893ce69e4803cd6d3c5302bc03522f520c909f401495cc651ee4b0c405dc26
#   Stored in directory: c:\users\sambh\appdata\local\pip\cache\wheels\74\47\c4\678b0a3d5213e2f8500f3ea0f8dc3c81478e5b806c557dff58
# Successfully built pyod plotly-resampler fugue-sql-antlr pymeeus
# Installing collected packages: trace-updater, sqlglot, pymeeus, korean-lunar-calendar, ephem, dash-table, dash-html-components, dash-core-components, antlr4-python3-runtime, slicer, retrying, pyarrow, protobuf, orjson, multidict, lightning-utilities, importlib-resources, graphviz, fs, frozenlist, Cython, convertdate, async-timeout, ansi2html, yarl, xgboost, torchmetrics, tensorboardX, LunarCalendar, holidays, aiosignal, triad, shap, pyod, nfoursid, lightgbm, dash, cmdstanpy, catboost, aiohttp, prophet, pmdarima, fugue-sql-antlr, adagio, tbats, qpd, pytorch-lightning, jupyter-dash, plotly-resampler, fugue, statsforecast, darts
# Successfully installed Cython-0.29.35 LunarCalendar-0.0.9 adagio-0.2.4 aiohttp-3.8.4 aiosignal-1.3.1 ansi2html-1.8.0 antlr4-python3-runtime-4.11.1 async-timeout-4.0.2 catboost-1.2 cmdstanpy-1.1.0 convertdate-2.4.0 darts-0.24.0 dash-2.10.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 ephem-4.1.4 frozenlist-1.3.3 fs-2.4.16 fugue-0.8.4 fugue-sql-antlr-0.1.6 graphviz-0.20.1 holidays-0.25 importlib-resources-5.12.0 jupyter-dash-0.4.2 korean-lunar-calendar-0.3.1 lightgbm-3.3.5 lightning-utilities-0.8.0 multidict-6.0.4 nfoursid-1.0.1 orjson-3.9.0 plotly-resampler-0.8.3.2 pmdarima-2.0.3 prophet-1.1.4 protobuf-3.20.3 pyarrow-12.0.0 pymeeus-0.5.12 pyod-1.0.9 pytorch-lightning-2.0.2 qpd-0.4.1 retrying-1.3.4 shap-0.41.0 slicer-0.0.7 sqlglot-15.0.0 statsforecast-1.5.0 tbats-1.1.3 tensorboardX-2.6 torchmetrics-0.11.4 trace-updater-0.0.9.1 triad-0.8.9 xgboost-1.7.5 yarl-1.9.2

# %%
from darts.datasets import AirPassengersDataset, MonthlyMilkDataset

# %%
AirPassengersDataset().load().pd_dataframe()
# Out:
# component   #Passengers
# Month
# 1949-01-01        112.0
# 1949-02-01        118.0
# 1949-03-01        132.0
# 1949-04-01        129.0
# 1949-05-01        121.0
# ...                 ...
# 1960-08-01        606.0
# 1960-09-01        508.0
# 1960-10-01        461.0
# 1960-11-01        390.0
# 1960-12-01        432.0
#
# [144 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
series_air = AirPassengersDataset().load()
series_milk = MonthlyMilkDataset().load()

series_air.plot(label='number of air passengers')
series_milk.plot(label='Pounds of milk produced per cow')
plt.legend()

# %%
from darts.dataprocessing.transformers import Scaler
scaler_air, scaler_milk = Scaler(), Scaler()
series_air_scaled = scaler_air.fit_transform(series_air)
series_milk_scaled = scaler_milk.fit_transform(series_milk)

series_air_scaled.plot(label = 'air')
series_milk_scaled.plot(label = 'milk')
plt.legend();

# %%
# Train And Validation Split
train_air, val_air = series_air_scaled[:-36], series_air_scaled[-36:]
train_milk, val_milk = series_milk_scaled[:-36], series_milk_scaled[-36:]

# %%
from darts import TimeSeries
from darts.utils.timeseries_generation import gaussian_timeseries, linear_timeseries, sine_timeseries
from darts.models import RNNModel, TCNModel, TransformerModel, NBEATSModel, BlockRNNModel
from darts.metrics import mape, smape

# %%
model_air_milk = NBEATSModel(input_chunk_length=24, output_chunk_length=12, n_epochs=100, random_state=0)

# %%
model_air_milk.fit([train_air, train_milk], verbose=True)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.2 M
# ---------------------------------------------------
# 6.2 M     Trainable params
# 1.4 K     Non-trainable params
# 6.2 M     Total params
# 24.787    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# NBEATSModel(generic_architecture=True, num_stacks=30, num_blocks=1, num_layers=4, layer_widths=256, expansion_coefficient_dim=5, trend_polynomial_degree=2, dropout=0.0, activation=ReLU, input_chunk_length=24, output_chunk_length=12, n_epochs=100, random_state=0)

# %%
pred = model_air_milk.predict(n=36, series=train_air)

series_air_scaled.plot(label='actual')
pred.plot(label='forecast')
plt.legend();
print('MAPE = {:.2f}%'.format(mape(series_air_scaled, pred)))
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# MAPE = 7.60%

# %%
pred = model_air_milk.predict(n=36, series=train_milk)

series_milk_scaled.plot(label='actual')
pred.plot(label='forecast')
plt.legend();
print('MAPE = {:.2f}%'.format(mape(series_milk_scaled, pred)))
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# MAPE = 13.49%
